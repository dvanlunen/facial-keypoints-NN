# %%
import numpy as np
import pandas as pd

# %%
TRAIN_DATA = '../data/training.csv'
TEST_DATA = '../data/test.csv'

# %%
df_train = pd.read_csv(TRAIN_DATA)
df_test = pd.read_csv(TEST_DATA)

# %%
# describe the data
df_train.describe()
# Out:
#        left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# count        7039.000000        7039.000000         7036.000000
# mean           66.359021          37.651234           30.306102
# std             3.448233           3.152926            3.083230
# min            22.763345           1.616512            0.686592
# 25%            65.082895          35.900451           28.783339
# 50%            66.497566          37.528055           30.251378
# 75%            68.024752          39.258449           31.768334
# max            94.689280          80.502649           85.039381
#
#        right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# count         7036.000000              2271.000000              2271.000000
# mean            37.976943                59.159339                37.944752
# std              3.033621                 2.690354                 2.307332
# min              4.091264                19.064954                27.190098
# ...

# %% [markdown]
# There are missing values in a number of the labels. Explore more exactly:

# %%
df_train.isnull().sum()
# Out:
# left_eye_center_x              10
# left_eye_center_y              10
# right_eye_center_x             13
# right_eye_center_y             13
# left_eye_inner_corner_x      4778
# left_eye_inner_corner_y      4778
# left_eye_outer_corner_x      4782
# left_eye_outer_corner_y      4782
# right_eye_inner_corner_x     4781
# right_eye_inner_corner_y     4781
# right_eye_outer_corner_x     4781
# right_eye_outer_corner_y     4781
# left_eyebrow_inner_end_x     4779
# left_eyebrow_inner_end_y     4779
# left_eyebrow_outer_end_x     4824
# left_eyebrow_outer_end_y     4824
# right_eyebrow_inner_end_x    4779
# right_eyebrow_inner_end_y    4779
# right_eyebrow_outer_end_x    4813
# right_eyebrow_outer_end_y    4813
# nose_tip_x                      0
# nose_tip_y                      0
# mouth_left_corner_x          4780
# mouth_left_corner_y          4780
# mouth_right_corner_x         4779
# mouth_right_corner_y         4779
# mouth_center_top_lip_x       4774
# ...

# %% [markdown]
# See how they occur together

# %%
labels = list(df_train.columns.difference(['Image']))
(df_train.isnull()
 .groupby(labels)
 .apply(lambda x: np.ma.size(x, axis=1))
 .reset_index(level=labels, name="n_rows")
 .sort_values(by=['n_rows'], ascending=False)
)
# Out:
#     left_eye_center_x  left_eye_center_y  left_eye_inner_corner_x  \
# 38              False              False                     True
# 0               False              False                    False
# 19              False              False                    False
# 1               False              False                    False
# 15              False              False                    False
# 39              False              False                     True
# 20              False              False                    False
# 29              False              False                    False
# 10              False              False                    False
# 28              False              False                    False
# 36              False              False                     True
# 17              False              False                    False
# 16              False              False                    False
# ...

# %% [markdown]
# There are the largest number of cases with the center of the eyes and no other labels. The second largest group contains all the labels. After this there is a scattering of missings that don't make up a large portion of the data.
